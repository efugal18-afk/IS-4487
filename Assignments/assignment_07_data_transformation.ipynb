# %% [markdown]
# # IS 4487 Assignment 7: Data Transformation with Airbnb Listings
#
# In this assignment, you will:
# - Load the Airbnb dataset you cleaned in Assignment 6
# - Apply data transformation techniques like scaling, binning, encoding, and feature creation
# - Make the dataset easier to use for tasks like pricing analysis, guest segmentation, or listing recommendations
# - Practice writing up your analysis clearly so a business audience — like a host, marketing manager, or city partner — could understand it
#
# ## Why This Matters
#
# Airbnb analysts, hosts, and city partners rely on clean and well-structured data to make smart decisions. Whether they’re adjusting prices, identifying high-performing listings, or designing better guest experiences, they need data that’s transformed, organized, and ready for use.
#
# This assignment helps you practice that kind of real-world thinking: taking messy real data and getting it ready for action.
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Assignments/assignment_07_data_transformation.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Dataset Description
#
# The dataset you'll be using is a **detailed Airbnb listing file**, available from [Inside Airbnb](https://insideairbnb.com/get-the-data/).
#
# Each row represents one property listing. The columns include:
#
# - **Host attributes** (e.g., host ID, host name, host response time)
# - **Listing details** (e.g., price, room type, minimum nights, availability)
# - **Location data** (e.g., neighborhood, latitude/longitude)
# - **Property characteristics** (e.g., number of bedrooms, amenities, accommodates)
# - **Calendar/booking variables** (e.g., last review date, number of reviews)
#
# The schema is consistent across cities, so you can expect similar columns regardless of the location you choose.

# %% [markdown]
# ## 1. Setup and Load Your Data
#
# You'll be working with the `cleaned_airbnb_data_6.csv` file you exported from Assignment 6. (Note: If you had significant errors with assignment 6, you can use the file named "airbnb_listings.csv" in the DataSets folder on GitHub as a backup starting point.)
#
# ### Do the following:
# In Google Colab:
# - Click the folder icon on the left sidebar
# - Use the upload button to add your CSV file to the session
# - Then use the code block below to read it into your notebook
#
# Before getting started, make sure you import the libraries you'll need for this assignment:
# - `pandas`, `numpy` for data manipulation
# - `matplotlib.pyplot`, `seaborn` for visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('cleaned_airbnb_data_6.csv')
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  2.719000e+03  2.719000e+03  2.719000e+03          2719.000000
# mean   6.826871e+17  2.025093e+13  1.964293e+08            29.793674
# std    6.007108e+17  5.469756e-01  2.126421e+08            87.718333
# min    4.251500e+04  2.025093e+13  6.783700e+04             1.000000
# 25%    3.666163e+07  2.025093e+13  1.985540e+07             1.000000
# 50%    8.217198e+17  2.025093e+13  1.006785e+08             2.000000
# 75%    1.241315e+18  2.025093e+13  3.272458e+08             6.000000
# max    1.518815e+18  2.025093e+13  7.209425e+08           381.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                2719.000000  2719.000000  2719.000000   2719.000000
# mean                   42.984921    46.207896     6.143274      2.637734
# std                   118.048724     0.020215     0.025043      1.532355
# ...

# %% [markdown]
# ## 2. Check for Skew in a Numeric Column
#
# ### Business framing:
#
# Airbnb listings can have a wide range of values for things like price, availability, or reviews. These kinds of distributions can be hard to visualize, summarize, or model.
#
# ### Do the following:
# Choose one **numeric column** that appears skewed and do the following:
# - Plot a histogram
# - Apply a transformation (e.g., log or other method)
# - Plot again to compare
#
# ### In Your Response:
# 1. What column did you examine?
# 2. What transformation did you try, and why?
# 3. How did the transformed version help make the data more usable for analysis or stakeholder review?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(airbnb_df['bedrooms'].dropna(), bins=range(int(airbnb_df['bedrooms'].min()), int(airbnb_df['bedrooms'].max()) + 2), kde=False)
plt.title('Distribution of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Frequency')
plt.show()

# %%
df['bedrooms_log'] = np.log1p(df['bedrooms'])

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['bedrooms_log'].dropna(), kde=False)
plt.title('Distribution of Log-Transformed Bedrooms')
plt.xlabel('Log(1 + Number of Bedrooms)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1. For my column I decided to use "bedrooms" becasue it indicated decent variability but also a heavy skew with a abnormally high max value
#
# 2. The method of transformation I was initially going to use was binning but the data was so skewed it was only able to create two bins at the most, so instead I went with a Log transformation which created more bins for a more traditional looking histogram
#
# 3. The transformed data is more usable because it shrank the scale of the outlier and allowed to histogram to look more traditional in apperance rather than the original version which has one extreme outlier and most other values forced into just one bin, creating a very narrow distribution apperance.

# %% [markdown]
# ## 3. Scale Two Numeric Columns
#
# ### Business framing:
#
# If an analyst wanted to compare listing price to number of nights required, or create a model that weighs both, those values need to be on a similar scale.
#
# ### Do the following:
# - Pick two numeric columns with different value ranges (e.g. one column may have a min of 0 and a max of 255; another column may have a min of 100 and a max of 400)
# - Use Min-Max scaling on one column (the range should be “shrinked” down to just 0-1)
# - Use Z-score Normalization (aka standardization) on the other column.
# - Add 2 new columns to the dataset. These 2 new columns should be the ones you just created.
#
# ### In Your Response:
# 1. What two columns did you scale, and which methods did you use?
# 2. When might these scaled values be more useful than the originals?
# 3. Who at Airbnb might benefit from this transformation and why?

# %%
df[['review_scores_value', 'reviews_per_month']].describe()
# Out:
#        review_scores_value  reviews_per_month
# count          2104.000000        2104.000000
# mean              4.616982           1.069601
# std               0.441710           1.536592
# min               1.000000           0.010000
# 25%               4.500000           0.170000
# 50%               4.710000           0.490000
# 75%               4.890000           1.330000
# max               5.000000          14.680000

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Initialize MinMaxScaler
minmax_scaler = MinMaxScaler()
# Apply Min-Max scaling to 'reviews_per_month'
df['reviews_per_month_scaled'] = minmax_scaler.fit_transform(df[['reviews_per_month']])

# Initialize StandardScaler
standard_scaler = StandardScaler()
# Apply Z-score Normalization to 'review_scores_value'
df['review_scores_value_zscore'] = standard_scaler.fit_transform(df[['review_scores_value']])

# Display the original and scaled columns to verify
display(df[['reviews_per_month', 'reviews_per_month_scaled', 'review_scores_value', 'review_scores_value_zscore']].describe())
# Out:
#        reviews_per_month  reviews_per_month_scaled  review_scores_value  \
# count        2104.000000               2104.000000          2104.000000
# mean            1.069601                  0.072229             4.616982
# std             1.536592                  0.104744             0.441710
# min             0.010000                  0.000000             1.000000
# 25%             0.170000                  0.010907             4.500000
# 50%             0.490000                  0.032720             4.710000
# 75%             1.330000                  0.089980             4.890000
# max            14.680000                  1.000000             5.000000
#
#        review_scores_value_zscore
# count                2.104000e+03
# mean                -1.989114e-15
# std                  1.000238e+00
# min                 -8.190532e+00
# 25%                 -2.649016e-01
# 50%                  2.106362e-01
# 75%                  6.182401e-01
# max                  8.673314e-01

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1. I decided to use the review scores value and reviews per month columns for this step
#
# 2. I think the scaled values are more useful whenever someone is wanting to compare a spefic metric of the data without having to know the maximum. For example with a 0-1 scale we know the maximum is going to be 1, so we know all other vlaues are going to be proportional to a maximum value of 1. For example we can see the median reviews per month when the maximum is only a 0.03 and the 75% is 0.09, without knowing the median value, 75% or maximum value we can already infer based on the scaled number that most listings are getting very little reviews, and a small number of listings are getting almost all the reviews.
#
# 3. Anyone tasked with managing listing exposure might benifit by this transformed data because it helps them better contexualize the distrubution of lsitings reviews, and thus listings viewrship, with this if they notice many listings are getting little or no attnetion, they can alter thier listings engine to give less popular listings more explosure to viewers using an unfiltered engine.

# %% [markdown]
# ## 4. Group a Numeric Column into Categories
#
# ### Business framing:
#
# Let’s say an Airbnb marketing team wants to segment listings by review activity. They don’t want exact numbers — they just want to know if a listing has “low,” “medium,” or “high” review volume.
#
# ### Do the following:
#
# - Choose a numeric column that could be grouped (e.g., reviews, availability).
# - You’ll want to group the values of this column into 3 or 4 bins
# - Create a new column. The values of this column will be the labels: “Low”, “Medium”, and “High.” These labels should correspond to your bins.
#
# ### In Your Response:
# 1. What column did you group, and how many categories did you use?
# 2. Why might someone prefer this grouped view over raw numbers?
# 3. Who would this help at Airbnb, and how?

# %%
df['reviews_per_month_filled'] = df['reviews_per_month'].fillna(0)
df['reviews_per_month_category'] = pd.qcut(
    df['reviews_per_month_filled'],
    q=4,
    labels=['Low', 'Medium', 'High', 'Very High'],)
display(df['reviews_per_month_category'].value_counts())
# Out:
# reviews_per_month_category
# Low          718
# High         676
# Very High    669
# Medium       656
# Name: count, dtype: int64

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1. I decided to use reviews per month for this step, and group the data in 4 bins labeled low, medium high and very high to better show the outliers identified in a previous step.
#
# 2. Binning the data compared to looking at the raw numbers make for more efficent analysis, as it divided the raw numbers into sections.
#
# 3. This could help anyone at airbnb working in data analysis because these reviews per month so the data is cycling every month, becasue of this efficeint analysis, such as grouping data into bins will be helpful for those working in data analytics who need to view large amounts of data cyclically.

# %% [markdown]
# ## 5. Create Two New Business-Relevant Variables
#
# ### Business framing:
#
# Stakeholders often want to know things like: What’s the cost per night? Are listings geared toward long-term stays? These kinds of features aren’t always in the dataset — analysts create them.
#
# ### Do the following:
#
# - Think of two new columns you can create using the data you already have.
#   - One might be a ratio or interaction between columns (e.g., price ÷ nights).
#   - The other might be a flag based on a condition (e.g., stays longer than 30 days).
# - Add the new columns to your DataFrame.
#
# ### In Your Response:
# 1. What two new columns did you create?
# 2. Who would use them (e.g., host, manager, or platform)?
# 3. How could they help someone make a better decision?

# %%
df['no_rentals_30_days_plus'] = (df['availability_30'] == 30)

average_price = df['price'].mean()

df['price_above_average'] = df['price'] > average_price

display(df[['price', 'no_rentals_30_days_plus', 'price_above_average']].sort_values(by='price', ascending=False))
pd.set_option('display.max_rows', None)
# Out:
#         price  no_rentals_30_days_plus  price_above_average
# 2350  17250.0                    False                 True
# 2264  14000.0                    False                 True
# 1960   8461.0                    False                 True
# 2318   4000.0                    False                 True
# 337    2215.0                    False                 True
# 1290   2000.0                    False                 True
# 1238   2000.0                    False                 True
# 1193   2000.0                     True                 True
# 1564   1888.0                    False                 True
# 966    1439.0                     True                 True
# 62     1376.0                    False                 True
# 837    1287.0                    False                 True
# 1196   1051.0                    False                 True
# 1759   1035.0                    False                 True
# 468    1000.0                     True                 True
# ...

# %% [markdown]
# ### ✍️ Your Response: 🔧 🔧
# 1. The two new coloumns I created were both binary columns, One shows wheather or not a listing has been occupied in the last 30 days, the other shows weather or not a specifc lisitng is priced above or below the overall average.
#
# 2. The first new coloumn I created would be most helpful to the hosts, this new column tell hosts if their property has been used lately, and if not, price ajdustments or other adjustments may be needed. The second column displaying prices above the mean are most useful for the consumers, who may want to use that information to determine if the listing is a good value or not.
#
# 3.The 30 day vacancy could be an indicator to the host the price is too high or that there is another issue causing lack of interest. The average price variable is most applicable to the consumer as a compliment to other inofrmation to help determine if the listing offers a good deal or not.

# %% [markdown]
# ## 6. Encode a Categorical Column
#
# ### Business framing:
#
# Let’s say you’re helping the Airbnb data science team build a model to predict booking rates. Categorical columns like `room_type`, `neighbourhood`, or `cancellation_policy` can’t be used in models unless they’re converted to numbers.
#
# ### Do the following:
# - Choose one categorical column from your dataset (e.g., room type or neighborhood group)
# - Decide on an encoding method:
#   - Use one-hot encoding for nominal (unordered) categories
#   - Use ordinal encoding (a ranking) only if the categories have a clear order
# - Apply the encoding using `pandas` or another tool
# - Add the new encoded column(s) to your DataFrame
#
# ### ✍️ In your markdown:
# 1. What column did you encode and why?
# 2. What encoding method did you use?
# 3. How could this transformation help a pricing model, dashboard, or business report?

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
if 'host_response_time_ranked' in df.columns:
    df = df.drop(columns=['host_response_time_ranked'])
one_hot_cols_previous = [col for col in df.columns if col.startswith('host_response_time_')]
if one_hot_cols_previous:
    df = df.drop(columns=one_hot_cols_previous)
df_host_response_time = airbnb_df['host_response_time'].copy()
df_host_response_time = df_host_response_time.fillna('Unknown')
ordered_categories = [
    'within an hour',
    'within a few hours',
    'within a day',
    'a few days or more',
    'Unknown']
cat_type = CategoricalDtype(categories=ordered_categories, ordered=True)
df_host_response_time_categorical = df_host_response_time.astype(cat_type)
one_hot_encoded_df = pd.get_dummies(df_host_response_time_categorical, prefix='host_response_time')
df = pd.concat([df, one_hot_encoded_df], axis=1)
if 'host_response_time' in df.columns:
    df = df.drop(columns=['host_response_time'])
display(df.filter(like='host_response_time_').head())
# Out:
#    host_response_time_within an hour  host_response_time_within a few hours  \
# 0                              False                                  False
# 1                               True                                  False
# 2                               True                                  False
# 3                               True                                  False
# 4                              False                                   True
#
#    host_response_time_within a day  host_response_time_a few days or more  \
# 0                             True                                  False
# 1                            False                                  False
# 2                            False                                  False
# 3                            False                                  False
# 4                            False                                  False
#
#    host_response_time_Unknown
# 0                       False
# ...

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1. I decided to encode the column "Host Response Time" cloumn
# 2.I decided to use a ordinal encode method since the times can obviously be ranked based on how quick to how slow the response time of the host is.
# 3.Encoding these varibles into a binary output can be benficial to business models and analysis because it allows the different outputs of the original column to be segereated and then further created into various visuals as desired depending on the need of the business.

# %% [markdown]
# ## 7. Export Cleaned Data
#
# Before wrapping up, export your cleaned Airbnb dataset to a CSV file. You'll need this file for **Assignment 11**, where you'll use the data in a regression model.
#
# ### Do the following:
# Make sure your data has:
# - Cleaned and consistent column values
# - Proper data types for each column
# - Any unnecessary columns removed
#
# This file should be the version of your dataset that you’d feel confident sharing with a teammate or using for deeper analysis.
#
#
#
# ```
# # Explanation:
# # - "cleaned_airbnb_data_7.csv" is the name of the file that will be saved
# # - index=False prevents pandas from writing row numbers into the CSV
# # - The file will be saved to your working directory (in Colab, you'll need to download it manually. Once you see the data in your files tab, just click on the three dots, then click “download”)
# # - YOU MAY NEED TO PRESS “RUN” MULTIPLE TIMES IN ORDER FOR IT TO SHOW UP
# # - FOR SOME DEVICES, IT MAY TAKE A FEW MINUTES BEFORE YOUR FILE SHOWS UP
#
# ```

# %%
df.to_csv('cleaned_airbnb_data_7.csv', index=False)

# %% [markdown]
# ## 8. Reflection
#
# You’ve applied the same kinds of transformation techniques used in real Airbnb analytics projects — from pricing engines to host tools to tourism dashboards.
#
# Now step back and reflect.
#
# ### In Your Response:
# 1. What transformation step felt most important or interesting?
# 2. Which of your changes would be most useful to a host, analyst, or city planner?
# 3. If you were going to build a tool or dashboard, what would you do next with this data?
# 4. How does this relate to your customized learning outcome you created in canvas?

# %% [markdown]
# ### ✍️ Your Response: 🔧
#
# 1. Creating new variables based on custom/desired parameters in step 5 seemed the most benifical because it allows you to curate completely new variables as needed.
#
# 2. Making a new varaible for vacancy exceeding 30 days seemed the most benifical for hosts becasue it seems like it would be a good metric for the success of a hosts listing.
#
# 3. The next step I would do would be to create more visuals for this transformed data to better visualize the impact of the various variables including the new variables.
#
# 4. One of my learning outcomes was learning how to use python to better interpret data, being able to transform and visual data within python compliments this learning outcome quite well.

# %% [markdown]
# ## Submission Instructions
# ✅ Checklist:
# - All code cells run without error
# - All markdown responses are complete
# - Submit on Canvas as instructed

# %%
# !jupyter nbconvert --to html "assignment_07_FugalEric.ipynb"
# Out:
# [NbConvertApp] Converting notebook assignment_07_FugalEric.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Writing 595300 bytes to assignment_07_FugalEric.html
